# %%
class Person:
    
    name = 'Mehak'
    age = 22
    height = 5.6

# %%
print(Person.name)
# Out:
# Mehak

# %%
p1 = Person()
p2 = Person()

# %%
p1.name, p2.name, Person.name
# Out:
# ('Mehak', 'Mehak', 'Mehak')

# %%
print(id(p1.name), id(p2.name), id(Person.name), id(Person().name))
# Out:
# 1848090044848 1848090044848 1848090044848 1848090044848

# %%
p1.name = 'Abhijeet'

# %%
p1.name, p2.name, Person.name
# Out:
# ('Abhijeet', 'Mehak', 'Mehak')

# %%
print(id(p1.name), id(p2.name), id(Person.name), id(Person().name))
# Out:
# 1848103739120 1848090044848 1848090044848 1848090044848

# %%
a = 10

def temp():
    a = 5
    print(a)

# %%
temp()
# Out:
# 5

# %%
print(p1.height, p2.height, Person.height)
print(id(p1.height), id(p2.height), id(Person.height), id(Person().height))
# Out:
# 5.6 5.6 5.6
# 1848090056656 1848090056656 1848090056656 1848090056656

# %%
abcd = 'Mehak'

# %%
p1.name = p2.name

# %%
p1.name, p2.name, Person.name
# Out:
# ('Mehak', 'Mehak', 'Mehak')

# %%
print(id(p1.name), id(p2.name), id(Person.name), id(Person().name), id(abcd))
# Out:
# 1848090044848 1848090044848 1848090044848 1848090044848 1848090044848

# %%
var1 = 'Abhijeet'
var2 = 'Abhijeet'
print(id(var1), id(var2))
# Out:
# 1848103739120 1848103739120

# %%
var2 = 'Mehak'
print(id(var1), id(var2))
# Out:
# 1848103739120 1848090044848

# %%
var2 = 'Abhijeet'
print(id(var1), id(var2))
# Out:
# 1848103739120 1848103739120

# %% [markdown]
# ![image.png](attachment:image.png)
