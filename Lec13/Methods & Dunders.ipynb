# %%
class Person:
    
    name = 'Mehak'
    age = 22
    height = 5.6

# %%
print(Person.name)
# Out:
# Mehak

# %%
p1 = Person()
p2 = Person()

# %%
p1.name, p2.name, Person.name
# Out:
# ('Mehak', 'Mehak', 'Mehak')

# %%
print(id(p1.name), id(p2.name), id(Person.name), id(Person().name))
# Out:
# 2414301476848 2414301476848 2414301476848 2414301476848

# %%
p1.name = 'Abhijeet'

# %%
p1.name, p2.name, Person.name
# Out:
# ('Abhijeet', 'Mehak', 'Mehak')

# %%
print(id(p1.name), id(p2.name), id(Person.name), id(Person().name))
# Out:
# 2414301678384 2414301476848 2414301476848 2414301476848

# %%
a = 10

def temp():
    a = 5
    print(a)

# %%
temp()
# Out:
# 5

# %%
print(p1.height, p2.height, Person.height)
print(id(p1.height), id(p2.height), id(Person.height), id(Person().height))
# Out:
# 5.6 5.6 5.6
# 2414301436048 2414301436048 2414301436048 2414301436048

# %%
abcd = 'Mehak'

# %%
p1.name = p2.name

# %%
p1.name, p2.name, Person.name
# Out:
# ('Mehak', 'Mehak', 'Mehak')

# %%
print(id(p1.name), id(p2.name), id(Person.name), id(Person().name), id(abcd))
# Out:
# 2414301476848 2414301476848 2414301476848 2414301476848 2414301476848

# %%
var1 = 'Abhijeet'
var2 = 'Abhijeet'
print(id(var1), id(var2))
# Out:
# 2414301678384 2414301678384

# %%
var2 = 'Mehak'
print(id(var1), id(var2))
# Out:
# 2414301678384 2414301476848

# %%
var2 = 'Abhijeet'
print(id(var1), id(var2))
# Out:
# 2414301678384 2414301678384

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Student:
    
    name = 'Mehak'
    age = 20
    
    def temp(self, abcd):
        print('Hello World')

# %%
s1 = Student()
s2 = Student()

# %%
s2.temp(12)
# Out:
# Hello World

# %%
print(s1.name, s2.name, Student.name)
print(id(s1.name), id(s2.name), id(Student.name))
# Out:
# Mehak Mehak Mehak
# 2414301476848 2414301476848 2414301476848

# %%
s1.name = 'Mehak'

# %%
print(s1.name, s2.name, Student.name)
print(id(s1.name), id(s2.name), id(Student.name))
# Out:
# Mehak Mehak Mehak
# 2414301476848 2414301476848 2414301476848

# %%
# 2351254445872 2351254445872 2351254445872 2351254445872 2351254445872

# %%
Person.name = 'Harsh'

# %%
print(p1.name, p2.name, Person.name)
print(id(p1.name), id(p2.name), id(Person.name))
print(s1.name, s2.name, Student.name)
print(id(s1.name), id(s2.name), id(Student.name))
# Out:
# Mehak Harsh Harsh
# 2414301476848 2414300806512 2414300806512
# Mehak Mehak Mehak
# 2414301476848 2414301476848 2414301476848

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def temp():
    name = 'Mehak'
    print(id(name))
    return name

# %%
n = temp()
print(n, id(n))
# 2414301476848
# Out:
# 2414301476848
# Mehak 2414301476848

# %%
vars(Person)
# Out:
# mappingproxy({'__module__': '__main__',
#               'name': 'Harsh',
#               'age': 22,
#               'height': 5.6,
#               '__dict__': <attribute '__dict__' of 'Person' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Person' objects>,
#               '__doc__': None})

# %%
Person.name
# Out:
# 'Harsh'

# %%
class Person:
    
    living = True
    
    def __init__(self, name, age, height):   # Dunders
        print('Call ho gya')
        self.name = name
        self.age = age
        self.height = height

# %%
p1 = Person('Abhijeet', 23, 5)
# Out:
# Call ho gya

# %%
p2 = Person('Mehak', 22, 5.6)
# Out:
# Call ho gya

# %%
print(p2.name, p1.name)
print(id(p2.name), id(p1.name), id(Person))
# Out:
# Mehak Abhijeet
# 2414301476848 2414301678384 2414288776912
